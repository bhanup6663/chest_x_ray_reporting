# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanup6663/chest_x_ray_reporting/blob/main/fasterCNN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/resized_images.zip -d /content/

# %%
# !pip install bbox_visualizer
# !pip install torchvision
# !pip install pydicom

# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from torch.optim.lr_scheduler import ReduceLROnPlateau

import cv2
from skimage import io, exposure
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import bbox_visualizer as bbv

import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut
from glob import glob
from skimage import exposure

import torch

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SequentialSampler
import torchvision

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
from torchvision.ops import box_iou

import shutil

import warnings

warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(os.path.join("train1.csv"))
dataset.head()
# Out:
#                            image_id          class_name  class_id rad_id  \
# 0  50a418190bc3fb1ef1633bf9678929b3          No finding        14    R11
# 1  21a10246a5ec7af151081d0cd6d65dc9          No finding        14     R7
# 2  9a5094b2563a1ef3ff50dc5c7ff71345        Cardiomegaly         3    R10
# 3  051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 4  063319de25ce7edb9b1c6b8881290140          No finding        14    R10
#
#       x_min     y_min     x_max     y_max   width  height
# 0       NaN       NaN       NaN       NaN  2332.0  2580.0
# 1       NaN       NaN       NaN       NaN  2954.0  3159.0
# 2  0.332212  0.588613  0.794712  0.783818  2080.0  2336.0
# 3  0.548611  0.257986  0.699219  0.353819  2304.0  2880.0
# 4       NaN       NaN       NaN       NaN  2540.0  3072.0

# %%
dataset_new = dataset[dataset.class_name!='No finding'].reset_index(drop=True)

# %%
class_brands = {
    0: 'Aortic enlargement',
    1: 'Atelectasis',
    2: 'Calcification',
    3: 'Cardiomegaly',
    4: 'Consolidation',
    5: 'ILD',
    6: 'Infiltration',
    7: 'Lung Opacity',
    8: 'Nodule/Mass',
    9: 'Other lesion',
    10: 'Pleural effusion',
    11: 'Pleural thickening',
    12: 'Pneumothorax',
    13: 'Pulmonary fibrosis'
}

# %%
num_classes = 15

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

in_features = model.roi_heads.box_predictor.cls_score.in_features

model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# %%
def set_device():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    return device

# %%
device=set_device()

# %%
model.to(device)
params = [p for p in model.parameters() if p.requires_grad]

# %%
def get_train_transform():
    return A.Compose([ToTensorV2(),], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

def get_valid_transform():
    return A.Compose([ToTensorV2(),], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
class LungsAnnotationDataset(Dataset):
    def __init__(self, dataframe, image_dir, transforms=None):
        super().__init__()
        self.image_ids = dataframe['image_id'].unique()
        self.df = dataframe
        self.image_dir = image_dir
        self.transforms = transforms

    def __getitem__(self, index: int):
        image_id = self.image_ids[index]
        records = self.df[self.df['image_id'] == image_id]

        image = io.imread(f'{self.image_dir}/{image_id}.png')

        # Normalize the image
        image = image / 255.0  # pixel values are in the range [0, 255]
        image = exposure.equalize_hist(image)
        image = image.astype('float32')

        # If the image has 3 channels already (like RGB), no need to stack, else ensure 3 channels
        if image.ndim == 2:  # If the image is grayscale, convert to 3 channels
            image = np.stack([image, image, image], axis=-1)

        # Ensure the image is in the correct (C, H, W) format
        if image.shape[2] == 3:  # Check if image is in (H, W, C)
            image = image.transpose(2, 0, 1)  # Convert from (H, W, C) to (C, H, W)

        # Get bounding boxes and other details
        boxes = records[['x_min', 'y_min', 'x_max', 'y_max']].values

        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        area = torch.as_tensor(area, dtype=torch.float32)

        labels = records.class_id.values + 1
        iscrowd = torch.zeros((records.shape[0],), dtype=torch.int64)

        target = {
            'boxes': torch.tensor(boxes, dtype=torch.float32),
            'labels': torch.tensor(labels, dtype=torch.int64),
            'area': area,
            'iscrowd': iscrowd
        }

        # Apply transformations if available (pass normalized boxes)
        if self.transforms:
            sample = {
                'image': image,
                'bboxes': target['boxes'],
                'labels': labels
            }
            sample = self.transforms(**sample)
            image = sample['image']
            target['boxes'] = torch.tensor(sample['bboxes'], dtype=torch.float32)

        # Denormalize boxes AFTER transformations (if you need pixel coordinates)
        target['boxes'][:, [0, 2]] = target['boxes'][:, [0, 2]] * 512
        target['boxes'][:, [1, 3]] = target['boxes'][:, [1, 3]] * 512

        return image, target


    def __len__(self):
        return len(self.image_ids)

# %%
def collate_fn(batch):
    images, targets = zip(*batch)
    images = [image.permute(1, 2, 0) if image.shape[0] != 3 else image for image in images]
    return torch.stack(images), targets

# %%
lr_scheduler = None

num_epochs = 50

# %%
class Averager:
    def __init__(self):
        self.current_total = 0.0
        self.iterations = 0.0

    def send(self, value):
        self.current_total += value
        self.iterations += 1

    @property
    def value(self):
        if self.iterations == 0:
            return 0
        else:
            return 1.0 * self.current_total / self.iterations

    def reset(self):
        self.current_total = 0.0
        self.iterations = 0.0

# %%
def calculate_iou(pred_boxes, gt_boxes):
    """
    Calculate IoU (Intersection over Union) between predicted and ground truth boxes.

    Args:
        pred_boxes (Tensor): Predicted bounding boxes, shape [num_pred_boxes, 4].
        gt_boxes (Tensor): Ground truth bounding boxes, shape [num_gt_boxes, 4].

    Returns:
        Tensor: IoU scores, shape [num_pred_boxes, num_gt_boxes].
    """
    return box_iou(pred_boxes, gt_boxes)

# %%
def train_model(train_dataset, val_dataset, fold):
    # Initialize data loaders
    train_data_loader = DataLoader(
        train_dataset,
        batch_size=10,
        shuffle=True,
        num_workers=4,
        collate_fn=collate_fn,
        prefetch_factor=4
    )

    val_data_loader = DataLoader(
        val_dataset,
        batch_size=3,
        shuffle=False,
        num_workers=4,
        collate_fn=collate_fn,
        prefetch_factor=4
    )

    # Initialize Averager instances for loss tracking
    loss_hist = Averager()
    val_loss_hist = Averager()

    # Initialize optimizer and scheduler
    optimizer = torch.optim.Adam(params, lr=0.0005, weight_decay=0.0005)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=10, factor=0.5, verbose=True)

    for epoch in range(num_epochs):
        loss_hist.reset()  # Reset Averager instance for each epoch
        model.train()  # Set model to training mode

        for itr, (images, targets) in enumerate(train_data_loader, 1):
            optimizer.zero_grad()
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            loss_dict = model(images, targets)

            if isinstance(loss_dict, dict):
                # Extract individual losses
                loss_classifier = loss_dict['loss_classifier']
                loss_box_reg = loss_dict['loss_box_reg']
                loss_objectness = loss_dict['loss_objectness']
                loss_rpn_box_reg = loss_dict['loss_rpn_box_reg']

                # Compute total loss
                losses = (loss_objectness +
                          10 * loss_classifier +
                          10 * loss_rpn_box_reg +
                          0.5 * loss_box_reg ** 2)

                # Check for NaNs in the losses
                if torch.isnan(losses).any():
                    print(f"NaN detected in losses: {losses}")
                    continue

                loss_value = losses.item()
                loss_hist.send(loss_value)

                losses.backward()
                optimizer.step()

                if itr % 100 == 0:
                    print(f"Fold #{fold} Epoch #{epoch+1} Iteration #{itr}/{len(train_data_loader)} loss: {loss_hist.value:.4f}")


        iou_hist = Averager()
        # Validation phase
        model.eval()
        with torch.no_grad():
            for images, targets in val_data_loader:
                images = [image.to(device) for image in images]
                targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

                # Get model predictions (boxes and labels)
                outputs = model(images)

                for output, target in zip(outputs, targets):
                    pred_boxes = output['boxes']
                    gt_boxes = target['boxes']

                    # Calculate IoU
                    iou = calculate_iou(pred_boxes, gt_boxes)

                    # Append average IoU for each image
                    iou_hist.send(iou.mean().item())

            avg_iou = iou_hist.value
            print(f"Fold #{fold} Epoch #{epoch+1} Validation IoU: {avg_iou:.4f}")

        # Update learning rate based on average IoU
        scheduler.step(avg_iou)

        # Save model checkpoint every 10 epochs
        if (epoch + 1) % 10 == 0:
            checkpoint_path = f"model_fasterRCNN_fold{fold}_epoch{epoch+1}.pth"
            print(f"Saving model checkpoint at epoch {epoch+1}...")
            torch.save(model.state_dict(), checkpoint_path)
            shutil.copy(checkpoint_path, f'/content/drive/MyDrive/x_ray_models/{checkpoint_path}')


    # Save final model state after the last epoch
    final_model_path = f"model_fasterRCNN_fold{fold}_final.pth"
    print(f"Saving final model state for fold #{fold}...")
    torch.save(model.state_dict(), final_model_path)
    shutil.copy(final_model_path, f'/content/drive/MyDrive/x_ray_models/{final_model_path}')

# %%
DIR_TRAIN = os.path.join( "resized_images")

train_df, valid_df = train_test_split(dataset_new, test_size=0.20, random_state=42)

train_dataset = LungsAnnotationDataset(train_df, DIR_TRAIN,get_train_transform())
valid_dataset = LungsAnnotationDataset(valid_df, DIR_TRAIN,get_valid_transform())

# %%
k = 1
df = dataset_new.sample(frac=1).reset_index(drop=True)
y = dataset_new.class_id.values

# Use GroupKFold to split the dataset
kfold = model_selection.GroupKFold(n_splits=5)

# Loop over each fold and perform training and validation
for train_index, val_index in kfold.split(df, y, groups=df.image_id.values):
    train_dataset = LungsAnnotationDataset(df.loc[train_index], DIR_TRAIN, get_train_transform())
    val_dataset = LungsAnnotationDataset(df.loc[val_index], DIR_TRAIN, get_valid_transform())

    # Train and validate the model
    train_model(train_dataset, val_dataset, k)

    k += 1
# Out:
# Fold #1 Epoch #1 Iteration #100/352 loss: 4.9124
# Fold #1 Epoch #1 Iteration #200/352 loss: 4.4151
# Fold #1 Epoch #1 Iteration #300/352 loss: 4.1226
# Fold #1 Epoch #1 Validation IoU: 0.0464
# Fold #1 Epoch #2 Iteration #100/352 loss: 3.5590
# Fold #1 Epoch #2 Iteration #200/352 loss: 3.5632
# Fold #1 Epoch #2 Iteration #300/352 loss: 3.5356
# Fold #1 Epoch #2 Validation IoU: 0.0488
# Fold #1 Epoch #3 Iteration #100/352 loss: 3.4374
# Fold #1 Epoch #3 Iteration #200/352 loss: 3.4594
# Fold #1 Epoch #3 Iteration #300/352 loss: 3.4780
# Fold #1 Epoch #3 Validation IoU: 0.0587
# Fold #1 Epoch #4 Iteration #100/352 loss: 3.4982
# Fold #1 Epoch #4 Iteration #200/352 loss: 3.4127
# Fold #1 Epoch #4 Iteration #300/352 loss: 3.3967
# Fold #1 Epoch #4 Validation IoU: 0.0665
# Fold #1 Epoch #5 Iteration #100/352 loss: 3.4744
# Fold #1 Epoch #5 Iteration #200/352 loss: 3.4755
# Fold #1 Epoch #5 Iteration #300/352 loss: 3.4390
# Fold #1 Epoch #5 Validation IoU: 0.0692
# Fold #1 Epoch #6 Iteration #100/352 loss: 3.3563
# Fold #1 Epoch #6 Iteration #200/352 loss: 3.4186
# Fold #1 Epoch #6 Iteration #300/352 loss: 3.4182
# Fold #1 Epoch #6 Validation IoU: 0.0875
# Fold #1 Epoch #7 Iteration #100/352 loss: 3.3717
# Fold #1 Epoch #7 Iteration #200/352 loss: 3.3849
# Fold #1 Epoch #7 Iteration #300/352 loss: 3.3494
# Fold #1 Epoch #7 Validation IoU: 0.0635
# Fold #1 Epoch #8 Iteration #100/352 loss: 3.3221
# Fold #1 Epoch #8 Iteration #200/352 loss: 3.3436
# Fold #1 Epoch #8 Iteration #300/352 loss: 3.3442
# Fold #1 Epoch #8 Validation IoU: 0.0629
# Fold #1 Epoch #9 Iteration #100/352 loss: 3.2827
# Fold #1 Epoch #9 Iteration #200/352 loss: 3.3039
# Fold #1 Epoch #9 Iteration #300/352 loss: 3.2825
# Fold #1 Epoch #9 Validation IoU: 0.0712
# Fold #1 Epoch #10 Iteration #100/352 loss: 3.2092
# Fold #1 Epoch #10 Iteration #200/352 loss: 3.2218
# Fold #1 Epoch #10 Iteration #300/352 loss: 3.2759
# Fold #1 Epoch #10 Validation IoU: 0.0954
# Saving model checkpoint at epoch 10...
# Fold #1 Epoch #11 Iteration #100/352 loss: 3.1465
# Fold #1 Epoch #11 Iteration #200/352 loss: 3.1203
# Fold #1 Epoch #11 Iteration #300/352 loss: 3.1528
# Fold #1 Epoch #11 Validation IoU: 0.0986
# Fold #1 Epoch #12 Iteration #100/352 loss: 2.9774
# Fold #1 Epoch #12 Iteration #200/352 loss: 3.0655
# Fold #1 Epoch #12 Iteration #300/352 loss: 3.0917
# Fold #1 Epoch #12 Validation IoU: 0.0803
# Fold #1 Epoch #13 Iteration #100/352 loss: 2.7480
# Fold #1 Epoch #13 Iteration #200/352 loss: 2.8214
# Fold #1 Epoch #13 Iteration #300/352 loss: 2.8456
# Fold #1 Epoch #13 Validation IoU: 0.0934
# Fold #1 Epoch #14 Iteration #100/352 loss: 2.6831
# Fold #1 Epoch #14 Iteration #200/352 loss: 2.6543
# Fold #1 Epoch #14 Iteration #300/352 loss: 2.6969
# Fold #1 Epoch #14 Validation IoU: 0.0851
# Fold #1 Epoch #15 Iteration #100/352 loss: 2.4828
# Fold #1 Epoch #15 Iteration #200/352 loss: 2.5344
# Fold #1 Epoch #15 Iteration #300/352 loss: 2.5660
# Fold #1 Epoch #15 Validation IoU: 0.0834
# Fold #1 Epoch #16 Iteration #100/352 loss: 2.4465
# Fold #1 Epoch #16 Iteration #200/352 loss: 2.4380
# Fold #1 Epoch #16 Iteration #300/352 loss: 2.4851
# Fold #1 Epoch #16 Validation IoU: 0.1058
# Fold #1 Epoch #17 Iteration #100/352 loss: 2.2908
# Fold #1 Epoch #17 Iteration #200/352 loss: 2.3483
# Fold #1 Epoch #17 Iteration #300/352 loss: 2.3940
# Fold #1 Epoch #17 Validation IoU: 0.0911
# Fold #1 Epoch #18 Iteration #100/352 loss: 2.2413
# Fold #1 Epoch #18 Iteration #200/352 loss: 2.2826
# Fold #1 Epoch #18 Iteration #300/352 loss: 2.3099
# Fold #1 Epoch #18 Validation IoU: 0.0955
# Fold #1 Epoch #19 Iteration #100/352 loss: 2.1885
# Fold #1 Epoch #19 Iteration #200/352 loss: 2.1679
# Fold #1 Epoch #19 Iteration #300/352 loss: 2.1869
# Fold #1 Epoch #19 Validation IoU: 0.0976
# Fold #1 Epoch #20 Iteration #100/352 loss: 2.0997
# Fold #1 Epoch #20 Iteration #200/352 loss: 2.1611
# Fold #1 Epoch #20 Iteration #300/352 loss: 2.1465
# Fold #1 Epoch #20 Validation IoU: 0.0980
# Saving model checkpoint at epoch 20...
# Fold #1 Epoch #21 Iteration #100/352 loss: 2.0280
# Fold #1 Epoch #21 Iteration #200/352 loss: 2.0248
# Fold #1 Epoch #21 Iteration #300/352 loss: 2.0337
# Fold #1 Epoch #21 Validation IoU: 0.0952
# Fold #1 Epoch #22 Iteration #100/352 loss: 1.9405
# Fold #1 Epoch #22 Iteration #200/352 loss: 1.9724
# Fold #1 Epoch #22 Iteration #300/352 loss: 1.9968
# Fold #1 Epoch #22 Validation IoU: 0.0928
# Fold #1 Epoch #23 Iteration #100/352 loss: 1.9042
# Fold #1 Epoch #23 Iteration #200/352 loss: 1.9019
# Fold #1 Epoch #23 Iteration #300/352 loss: 1.9051
# Fold #1 Epoch #23 Validation IoU: 0.0976
# Fold #1 Epoch #24 Iteration #100/352 loss: 1.6810
# Fold #1 Epoch #24 Iteration #200/352 loss: 1.6589
# Fold #1 Epoch #24 Iteration #300/352 loss: 1.6394
# Fold #1 Epoch #24 Validation IoU: 0.1284
# Fold #1 Epoch #25 Iteration #100/352 loss: 1.4403
# Fold #1 Epoch #25 Iteration #200/352 loss: 1.4480
# Fold #1 Epoch #25 Iteration #300/352 loss: 1.4755
# Fold #1 Epoch #25 Validation IoU: 0.1212
# Fold #1 Epoch #26 Iteration #100/352 loss: 1.3920
# Fold #1 Epoch #26 Iteration #200/352 loss: 1.4227
# Fold #1 Epoch #26 Iteration #300/352 loss: 1.4144
# Fold #1 Epoch #26 Validation IoU: nan
# Fold #1 Epoch #27 Iteration #100/352 loss: 1.3643
# Fold #1 Epoch #27 Iteration #200/352 loss: 1.3708
# Fold #1 Epoch #27 Iteration #300/352 loss: 1.3784
# Fold #1 Epoch #27 Validation IoU: 0.1135
# Fold #1 Epoch #28 Iteration #100/352 loss: 1.3325
# Fold #1 Epoch #28 Iteration #200/352 loss: 1.3584
# Fold #1 Epoch #28 Iteration #300/352 loss: 1.3562
# Fold #1 Epoch #28 Validation IoU: 0.1174
# Fold #1 Epoch #29 Iteration #100/352 loss: 1.3171
# Fold #1 Epoch #29 Iteration #200/352 loss: 1.3125
# Fold #1 Epoch #29 Iteration #300/352 loss: 1.3073
# Fold #1 Epoch #29 Validation IoU: nan
# Fold #1 Epoch #30 Iteration #100/352 loss: 1.2951
# Fold #1 Epoch #30 Iteration #200/352 loss: 1.2484
# Fold #1 Epoch #30 Iteration #300/352 loss: 1.2716
# Fold #1 Epoch #30 Validation IoU: 0.1342
# Saving model checkpoint at epoch 30...
# Fold #1 Epoch #31 Iteration #100/352 loss: 1.2350
# Fold #1 Epoch #31 Iteration #200/352 loss: 1.2547
# Fold #1 Epoch #31 Iteration #300/352 loss: 1.2463
# Fold #1 Epoch #31 Validation IoU: 0.1237
# Fold #1 Epoch #32 Iteration #100/352 loss: 1.1798
# Fold #1 Epoch #32 Iteration #200/352 loss: 1.2040
# Fold #1 Epoch #32 Iteration #300/352 loss: 1.2263
# Fold #1 Epoch #32 Validation IoU: 0.1321
# Fold #1 Epoch #33 Iteration #100/352 loss: 1.2135
# Fold #1 Epoch #33 Iteration #200/352 loss: 1.1967
# Fold #1 Epoch #33 Iteration #300/352 loss: 1.1947
# Fold #1 Epoch #33 Validation IoU: 0.1331
# Fold #1 Epoch #34 Iteration #100/352 loss: 1.1781
# Fold #1 Epoch #34 Iteration #200/352 loss: 1.1782
# Fold #1 Epoch #34 Iteration #300/352 loss: 1.1792
# Fold #1 Epoch #34 Validation IoU: nan
# Fold #1 Epoch #35 Iteration #100/352 loss: 1.0873
# Fold #1 Epoch #35 Iteration #200/352 loss: 1.0604
# Fold #1 Epoch #35 Iteration #300/352 loss: 1.0523
# Fold #1 Epoch #35 Validation IoU: nan
# Fold #1 Epoch #36 Iteration #100/352 loss: 0.9345
# Fold #1 Epoch #36 Iteration #200/352 loss: 0.9327
# Fold #1 Epoch #36 Iteration #300/352 loss: 0.9465
# Fold #1 Epoch #36 Validation IoU: nan
# Fold #1 Epoch #37 Iteration #100/352 loss: 0.9150
# Fold #1 Epoch #37 Iteration #200/352 loss: 0.9062
# Fold #1 Epoch #37 Iteration #300/352 loss: 0.9137
# Fold #1 Epoch #37 Validation IoU: nan
# Fold #1 Epoch #38 Iteration #100/352 loss: 0.9375
# Fold #1 Epoch #38 Iteration #200/352 loss: 0.9311
# Fold #1 Epoch #38 Iteration #300/352 loss: 0.9179
# Fold #1 Epoch #38 Validation IoU: nan
# Fold #1 Epoch #39 Iteration #100/352 loss: 0.8957
# Fold #1 Epoch #39 Iteration #200/352 loss: 0.9038
# Fold #1 Epoch #39 Iteration #300/352 loss: 0.8980
# Fold #1 Epoch #39 Validation IoU: 0.1484
# Fold #1 Epoch #40 Iteration #100/352 loss: 0.8735
# Fold #1 Epoch #40 Iteration #200/352 loss: 0.8724
# Fold #1 Epoch #40 Iteration #300/352 loss: 0.8898
# Fold #1 Epoch #40 Validation IoU: 0.1439
# Saving model checkpoint at epoch 40...
# Fold #1 Epoch #41 Iteration #100/352 loss: 0.8756
# Fold #1 Epoch #41 Iteration #200/352 loss: 0.8532
# Fold #1 Epoch #41 Iteration #300/352 loss: 0.8646
# Fold #1 Epoch #41 Validation IoU: nan
# Fold #1 Epoch #42 Iteration #100/352 loss: 0.8699
# Fold #1 Epoch #42 Iteration #200/352 loss: 0.8653
# Fold #1 Epoch #42 Iteration #300/352 loss: 0.8599
# Fold #1 Epoch #42 Validation IoU: nan
# Fold #1 Epoch #43 Iteration #100/352 loss: 0.8389
# Fold #1 Epoch #43 Iteration #200/352 loss: 0.8263
# Fold #1 Epoch #43 Iteration #300/352 loss: 0.8404
# Fold #1 Epoch #43 Validation IoU: 0.1463
# Fold #1 Epoch #44 Iteration #100/352 loss: 0.8561
# Fold #1 Epoch #44 Iteration #200/352 loss: 0.8575
# Fold #1 Epoch #44 Iteration #300/352 loss: 0.8448
# Fold #1 Epoch #44 Validation IoU: nan
# Fold #1 Epoch #45 Iteration #100/352 loss: 0.8189
# Fold #1 Epoch #45 Iteration #200/352 loss: 0.8212
# Fold #1 Epoch #45 Iteration #300/352 loss: 0.8261
# Fold #1 Epoch #45 Validation IoU: 0.1335
# Fold #1 Epoch #46 Iteration #100/352 loss: 0.7758
# Fold #1 Epoch #46 Iteration #200/352 loss: 0.7545
# Fold #1 Epoch #46 Iteration #300/352 loss: 0.7622
# Fold #1 Epoch #46 Validation IoU: 0.1548
# Fold #1 Epoch #47 Iteration #100/352 loss: 0.7199
# Fold #1 Epoch #47 Iteration #200/352 loss: 0.7061
# Fold #1 Epoch #47 Iteration #300/352 loss: 0.7103
# Fold #1 Epoch #47 Validation IoU: nan
# Fold #1 Epoch #48 Iteration #100/352 loss: 0.7107
# Fold #1 Epoch #48 Iteration #200/352 loss: 0.6911
# Fold #1 Epoch #48 Iteration #300/352 loss: 0.6820
# Fold #1 Epoch #48 Validation IoU: nan
# Fold #1 Epoch #49 Iteration #100/352 loss: 0.6740
# Fold #1 Epoch #49 Iteration #200/352 loss: 0.6787
# Fold #1 Epoch #49 Iteration #300/352 loss: 0.6761
# Fold #1 Epoch #49 Validation IoU: nan
# Fold #1 Epoch #50 Iteration #100/352 loss: 0.6897
# Fold #1 Epoch #50 Iteration #200/352 loss: 0.6885
# Fold #1 Epoch #50 Iteration #300/352 loss: 0.6764
# Fold #1 Epoch #50 Validation IoU: nan
# Saving model checkpoint at epoch 50...
# Saving final model state for fold #1...
# Fold #2 Epoch #1 Iteration #100/352 loss: 2.7655
# Fold #2 Epoch #1 Iteration #200/352 loss: 2.7052
# Fold #2 Epoch #1 Iteration #300/352 loss: 2.7555
# Fold #2 Epoch #1 Validation IoU: 0.0826
# Fold #2 Epoch #2 Iteration #100/352 loss: 2.5721
# Fold #2 Epoch #2 Iteration #200/352 loss: 2.5978
# Fold #2 Epoch #2 Iteration #300/352 loss: 2.5961
# Fold #2 Epoch #2 Validation IoU: 0.1046
# Fold #2 Epoch #3 Iteration #100/352 loss: 2.4110
# Fold #2 Epoch #3 Iteration #200/352 loss: 2.4528
# Fold #2 Epoch #3 Iteration #300/352 loss: 2.5009
# Fold #2 Epoch #3 Validation IoU: 0.0828
# Fold #2 Epoch #4 Iteration #100/352 loss: 2.3011
# Fold #2 Epoch #4 Iteration #200/352 loss: 2.3971
# Fold #2 Epoch #4 Iteration #300/352 loss: 2.4383
# Fold #2 Epoch #4 Validation IoU: 0.0912
# Fold #2 Epoch #5 Iteration #100/352 loss: 2.3438
# Fold #2 Epoch #5 Iteration #200/352 loss: 2.3893
# Fold #2 Epoch #5 Iteration #300/352 loss: 2.3705
# Fold #2 Epoch #5 Validation IoU: 0.0822
# Fold #2 Epoch #6 Iteration #100/352 loss: 2.2139
# Fold #2 Epoch #6 Iteration #200/352 loss: 2.2696
# Fold #2 Epoch #6 Iteration #300/352 loss: 2.2879
# Fold #2 Epoch #6 Validation IoU: 0.0698
# Fold #2 Epoch #7 Iteration #100/352 loss: 2.2801
# Fold #2 Epoch #7 Iteration #200/352 loss: 2.2627
# Fold #2 Epoch #7 Iteration #300/352 loss: 2.2871
# Fold #2 Epoch #7 Validation IoU: 0.0770
# Fold #2 Epoch #8 Iteration #100/352 loss: 2.1753
# Fold #2 Epoch #8 Iteration #200/352 loss: 2.1907
# Fold #2 Epoch #8 Iteration #300/352 loss: 2.2333
# Fold #2 Epoch #8 Validation IoU: 0.1005
# Fold #2 Epoch #9 Iteration #100/352 loss: 2.1674
# Fold #2 Epoch #9 Iteration #200/352 loss: 2.1704
# Fold #2 Epoch #9 Iteration #300/352 loss: 2.1782
# Fold #2 Epoch #9 Validation IoU: 0.1039
# Fold #2 Epoch #10 Iteration #100/352 loss: 2.0577
# Fold #2 Epoch #10 Iteration #200/352 loss: 2.1099
# Fold #2 Epoch #10 Iteration #300/352 loss: 2.1443
# Fold #2 Epoch #10 Validation IoU: 0.0813
# Saving model checkpoint at epoch 10...
# Fold #2 Epoch #11 Iteration #100/352 loss: 2.0253
# Fold #2 Epoch #11 Iteration #200/352 loss: 2.0725
# Fold #2 Epoch #11 Iteration #300/352 loss: 2.0986
# Fold #2 Epoch #11 Validation IoU: 0.0800
# Fold #2 Epoch #12 Iteration #100/352 loss: 1.9931
# Fold #2 Epoch #12 Iteration #200/352 loss: 2.0024
# Fold #2 Epoch #12 Iteration #300/352 loss: 2.0772
# Fold #2 Epoch #12 Validation IoU: 0.0918
# Fold #2 Epoch #13 Iteration #100/352 loss: 2.0453
# Fold #2 Epoch #13 Iteration #200/352 loss: 2.0602
# Fold #2 Epoch #13 Iteration #300/352 loss: 2.0389
# Fold #2 Epoch #13 Validation IoU: 0.0880
# Fold #2 Epoch #14 Iteration #100/352 loss: 1.9304
# Fold #2 Epoch #14 Iteration #200/352 loss: 1.9935
# Fold #2 Epoch #14 Iteration #300/352 loss: 2.0151
# Fold #2 Epoch #14 Validation IoU: 0.0912
# Fold #2 Epoch #15 Iteration #100/352 loss: 1.8803
# Fold #2 Epoch #15 Iteration #200/352 loss: 1.9219
# Fold #2 Epoch #15 Iteration #300/352 loss: 1.9439
# Fold #2 Epoch #15 Validation IoU: 0.1018
# Fold #2 Epoch #16 Iteration #100/352 loss: 1.9298
# Fold #2 Epoch #16 Iteration #200/352 loss: 1.9105
# Fold #2 Epoch #16 Iteration #300/352 loss: 1.9401
# Fold #2 Epoch #16 Validation IoU: 0.1172
# Fold #2 Epoch #17 Iteration #100/352 loss: 1.8029
# Fold #2 Epoch #17 Iteration #200/352 loss: 1.8770
# Fold #2 Epoch #17 Iteration #300/352 loss: 1.8925
# Fold #2 Epoch #17 Validation IoU: 0.1007
# Fold #2 Epoch #18 Iteration #100/352 loss: 1.6406
# Fold #2 Epoch #18 Iteration #200/352 loss: 1.5826
# Fold #2 Epoch #18 Iteration #300/352 loss: 1.5762
# Fold #2 Epoch #18 Validation IoU: 0.1462
# Fold #2 Epoch #19 Iteration #100/352 loss: 1.3073
# Fold #2 Epoch #19 Iteration #200/352 loss: 1.3424
# Fold #2 Epoch #19 Iteration #300/352 loss: 1.3321
# Fold #2 Epoch #19 Validation IoU: 0.1421
# Fold #2 Epoch #20 Iteration #100/352 loss: 1.2345
# Fold #2 Epoch #20 Iteration #200/352 loss: 1.2609
# Fold #2 Epoch #20 Iteration #300/352 loss: 1.2850
# Fold #2 Epoch #20 Validation IoU: 0.1757
# Saving model checkpoint at epoch 20...
# Fold #2 Epoch #21 Iteration #100/352 loss: 1.2280
# Fold #2 Epoch #21 Iteration #200/352 loss: 1.2528
# Fold #2 Epoch #21 Iteration #300/352 loss: 1.2645
# Fold #2 Epoch #21 Validation IoU: 0.1418
# Fold #2 Epoch #22 Iteration #100/352 loss: 1.2553
# Fold #2 Epoch #22 Iteration #200/352 loss: 1.2489
# Fold #2 Epoch #22 Iteration #300/352 loss: 1.2528
# Fold #2 Epoch #22 Validation IoU: 0.1517
# Fold #2 Epoch #23 Iteration #100/352 loss: 1.2180
# Fold #2 Epoch #23 Iteration #200/352 loss: 1.2226
# Fold #2 Epoch #23 Iteration #300/352 loss: 1.2351
# Fold #2 Epoch #23 Validation IoU: 0.1301
# Fold #2 Epoch #24 Iteration #100/352 loss: 1.2118
# Fold #2 Epoch #24 Iteration #200/352 loss: 1.2301
# Fold #2 Epoch #24 Iteration #300/352 loss: 1.2429
# Fold #2 Epoch #24 Validation IoU: 0.1496
# Fold #2 Epoch #25 Iteration #100/352 loss: 1.1903
# Fold #2 Epoch #25 Iteration #200/352 loss: 1.2261
# Fold #2 Epoch #25 Iteration #300/352 loss: 1.2295
# Fold #2 Epoch #25 Validation IoU: nan
# Fold #2 Epoch #26 Iteration #100/352 loss: 1.2059
# Fold #2 Epoch #26 Iteration #200/352 loss: 1.2192
# Fold #2 Epoch #26 Iteration #300/352 loss: 1.2147
# Fold #2 Epoch #26 Validation IoU: 0.1452
# Fold #2 Epoch #27 Iteration #100/352 loss: 1.1984
# Fold #2 Epoch #27 Iteration #200/352 loss: 1.1957
# Fold #2 Epoch #27 Iteration #300/352 loss: 1.2042
# Fold #2 Epoch #27 Validation IoU: 0.1493
# Fold #2 Epoch #28 Iteration #100/352 loss: 1.1677
# Fold #2 Epoch #28 Iteration #200/352 loss: 1.2032
# Fold #2 Epoch #28 Iteration #300/352 loss: 1.2059
# Fold #2 Epoch #28 Validation IoU: 0.1229
# Fold #2 Epoch #29 Iteration #100/352 loss: 1.0623
# Fold #2 Epoch #29 Iteration #200/352 loss: 1.0453
# Fold #2 Epoch #29 Iteration #300/352 loss: 1.0402
# Fold #2 Epoch #29 Validation IoU: nan
# Fold #2 Epoch #30 Iteration #100/352 loss: 0.8917

# %%
from google.colab import runtime
runtime.unassign()
